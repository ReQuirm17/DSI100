# %%
import pandas as pd

# %%
df = pd.read_csv("Copy of FLW Online Sales_sun.csv")
df
# Out:
#      OrderDateNew            CustomerName         Region  CustomerState  \
# 0      1 Jan 2020   Tristan Henderson LLC  United States      Tennessee
# 1      1 Jan 2020         Emmanuel Garcia  United States          Texas
# 2      1 Jan 2020  Christian Hughes Group  United States       New York
# 3      1 Jan 2020       Geoffrey Gonzalez  United States  Massachusetts
# 4      1 Jan 2020    Eduardo Williams LLC  United States       New York
# ...           ...                     ...            ...            ...
# 4971  31 Dec 2020         Joy Ramos Group  United States  Massachusetts
# 4972  31 Dec 2020      Edward Parker Inc.  United States         Kansas
# 4973  31 Dec 2020       Catherine Cox LLC  United States      Minnesota
# 4974  31 Dec 2020              Susan Yang  United States     California
# 4975  31 Dec 2020     Dalton Parker Group  United States       Nebraska
#
#      CustomerType Flower  Month  OrderNumber                 Product  \
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of      OrderDateNew            CustomerName         Region  CustomerState  \
# 0      1 Jan 2020   Tristan Henderson LLC  United States      Tennessee
# 1      1 Jan 2020         Emmanuel Garcia  United States          Texas
# 2      1 Jan 2020  Christian Hughes Group  United States       New York
# 3      1 Jan 2020       Geoffrey Gonzalez  United States  Massachusetts
# 4      1 Jan 2020    Eduardo Williams LLC  United States       New York
# ...           ...                     ...            ...            ...
# 4971  31 Dec 2020         Joy Ramos Group  United States  Massachusetts
# 4972  31 Dec 2020      Edward Parker Inc.  United States         Kansas
# 4973  31 Dec 2020       Catherine Cox LLC  United States      Minnesota
# 4974  31 Dec 2020              Susan Yang  United States     California
# 4975  31 Dec 2020     Dalton Parker Group  United States       Nebraska
#
# ...

# %%
df["Total Sales"] = df["Total Sales"].fillna(df["Total Sales"].mean())
df
# Out:
#      OrderDateNew            CustomerName         Region  CustomerState  \
# 0      1 Jan 2020   Tristan Henderson LLC  United States      Tennessee
# 1      1 Jan 2020         Emmanuel Garcia  United States          Texas
# 2      1 Jan 2020  Christian Hughes Group  United States       New York
# 3      1 Jan 2020       Geoffrey Gonzalez  United States  Massachusetts
# 4      1 Jan 2020    Eduardo Williams LLC  United States       New York
# ...           ...                     ...            ...            ...
# 4971  31 Dec 2020         Joy Ramos Group  United States  Massachusetts
# 4972  31 Dec 2020      Edward Parker Inc.  United States         Kansas
# 4973  31 Dec 2020       Catherine Cox LLC  United States      Minnesota
# 4974  31 Dec 2020              Susan Yang  United States     California
# 4975  31 Dec 2020     Dalton Parker Group  United States       Nebraska
#
#      CustomerType Flower  Month  OrderNumber                 Product  \
# ...

# %%
df.notnull()
# Out:
#       OrderDateNew  CustomerName  Region  CustomerState  CustomerType  Flower  \
# 0             True          True    True           True          True    True
# 1             True          True    True           True          True    True
# 2             True          True    True           True          True    True
# 3             True          True    True           True          True    True
# 4             True          True    True           True          True    True
# ...            ...           ...     ...            ...           ...     ...
# 4971          True          True    True           True          True    True
# 4972          True          True    True           True          True    True
# 4973          True          True    True           True          True    True
# 4974          True          True    True           True          True    True
# 4975          True          True    True           True          True    True
#
# ...

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       OrderDateNew  CustomerName  Region  CustomerState  CustomerType  Flower  \
# 0            False         False   False          False         False   False
# 1            False         False   False          False         False   False
# 2            False         False   False          False         False   False
# 3            False         False   False          False         False   False
# 4            False         False   False          False         False   False
# ...            ...           ...     ...            ...           ...     ...
# 4971         False         False   False          False         False   False
# 4972         False         False   False          False         False   False
# 4973         False         False   False          False         False   False
# 4974         False         False   False          False         False   False
# ...

# %%
df.to_csv("sun_fix_NA.csv")
